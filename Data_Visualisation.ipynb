# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
olympic = pd.read_csv('input/athletes.csv')

# %%
data.head()
# Out:
#           id            name nationality     sex       dob  height  weight  \
# 0  736041664  A Jesus Garcia         ESP    male  10/17/69    1.72    64.0
# 1  532037425      A Lam Shin         KOR  female   9/23/86    1.68    56.0
# 2  435962603     Aaron Brown         CAN    male   5/27/92    1.98    79.0
# 3  521041435      Aaron Cook         MDA    male    1/2/91    1.83    80.0
# 4   33922579      Aaron Gate         NZL    male  11/26/90    1.81    71.0
#
#        sport  gold  silver  bronze
# 0  athletics     0       0       0
# 1    fencing     0       0       0
# 2  athletics     0       0       1
# 3  taekwondo     0       0       0
# 4    cycling     0       0       0

# %%
olympic[['nationality','sport']].groupby(by='sport').count().plot(kind="bar")

# %%
olympic[['height','weight','sex']].groupby(by='sex').max().plot(kind="bar")

# %%
olympic[['gold','silver','bronze','sex']].groupby(by='sex').max().plot(kind="bar")
plt.title("")

# %%
olympic[['gold','silver','bronze','sport']].groupby(by='sport').max().plot(kind="bar")

# %%
olympic.height.hist()

# %%
olympic.weight.hist()

# %%
olympic[['height','sport']].groupby(by ='sport').mean().plot(kind='bar')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-dd1b482d396f> in <module>()
# ----> 1 plt.barplot(x = 'nationality', y = 'sport', data=olympic)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'barplot'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11538 entries, 0 to 11537
# Data columns (total 11 columns):
# id             11538 non-null int64
# name           11538 non-null object
# nationality    11538 non-null object
# sex            11538 non-null object
# dob            11537 non-null object
# height         11208 non-null float64
# weight         10879 non-null float64
# sport          11538 non-null object
# gold           11538 non-null int64
# silver         11538 non-null int64
# bronze         11538 non-null int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 991.6+ KB

# %%
plt.subplot(211)
sns.countplot(x='nationality',data = olympic)
plt.subplot(222)
sns.countplot(x = 'sport', data=olympic)
plt.show()

# %%
plt.subplot(211)
sns.countplot(x='name',data = olympic)
plt.subplot(222)
sns.countplot(x = 'height', data=olympic)
plt.show()

# %%
plt.subplot(211)
sns.countplot(x='name',data = olympic)
plt.subplot(222)
sns.countplot(x = 'weight', data=olympic)
plt.show()

# %%
sns.barplot(x='gold',y='sport',data=olympic,ci=0)

# %%
sns.barplot(x='silver',y='sport',data=olympic,ci=0)

# %%
sns.barplot(x='bronze',y='sport',data=olympic,ci=0)

# %%
olympic['nationality'].head()
# Out:
# 0    ESP
# 1    KOR
# 2    CAN
# 3    MDA
# 4    NZL
# Name: nationality, dtype: object

# %%
olympic['id'].plot(kind='bar')
